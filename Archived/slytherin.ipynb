# %% [markdown]
# #### Q Table: Running this cell resets the table.

# %%
q = {}

# %% [markdown]
# #### Only needs to be run to reset snake.py module.

# %%
import snake, threading, time, random, queue, random
import tkinter as tk
import cupy as cp
directions = ["UP", "DOWN", "LEFT", "RIGHT"]

# %% [markdown]
# #### Hyperparameters.

# %%
epsilon = 0.1
discount = 0.8
rate = 2
many_info = False

# %% [markdown]
# #### Agent functions.

# %%
def flatten_state(state):
    flat = ""
    for y in state:
        for x in y:
            flat += str(int(x))
    return flat

# %%
def init_state(flat):
    q[flat] = cp.array([random.random(), random.random(), random.random(), random.random()])

# %%
def update(flat, action, reward, transition):
    if not transition in q:
        init_state(transition)

    if many_info:
        print()
        print("Updated Q Value for state: ")
        print(">> Function: {0} + {1}({2} + {3} * {4} - {5})".format(q[flat][action], rate, reward, discount, cp.max(q[transition]), q[flat]                 [action]))
    
    prev_value = q[flat][action]
    q[flat][action] = q[flat][action] + rate * (reward + discount * cp.max(q[transition]) - q[flat][action])
    
    if many_info:
        print(">> New value: " + str(q[flat][action]))
        print(">> Old value: " + str(prev_value))

# %%
def epsilon_greed(flat):
    p = random.random()

    if many_info:
        print()
        
    if p < epsilon:
        action = directions[random.randint(0, 3)]

        if many_info:
            print("Stepping game with random action: " + action)
        
        return action
    else:
        action = directions[int(cp.argmax(q[flat]))]
        
        if many_info:
            print("Stepping game with greedy action: " + action)
            print(">> Q UP: " + str(cp.max(q[flat][0])))
            print(">> Q DOWN: " + str(cp.max(q[flat][1])))
            print(">> Q LEFT: " + str(cp.max(q[flat][2])))
            print(">> Q RIGHT: " + str(cp.max(q[flat][3])))

        return action

# %%
def agent(game, epoch):
    if many_info:
        print("\n")
        print("===================================================")
    print("Agent thread started, epoch " + str(epoch) + ".")

    if not flatten_state(game.get_state()) in q:
        init_state(flatten_state(game.get_state()))

    time.sleep(0.01)

    while game.running:
        flat_t = flatten_state(game.get_state())
        action_t = epsilon_greed(flat_t)

        game.step(action_t)

        while return_queue.empty():
            if not game.running:
                break

        state_reward = return_queue.get()
        update(flat_t, directions.index(action_t), state_reward[1], flatten_state(state_reward[0]))

    print("Agent thread joined, scoring " + str(game.score) + " points.")

# %% [markdown]
# #### Start the game, and initialize the agent thread.

# %%
game = snake.game(queue.Queue(1))

for x in range(1000):
    return_queue = queue.Queue(1)

    agent_thread = threading.Thread(target=agent, args=(game, x))
    agent_thread.start()

    game.start(return_queue)
    agent_thread.join()

game.w.destroy()
# Out:
# Agent thread started, epoch 0.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 1.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 2.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 3.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 4.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 5.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 6.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 7.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 8.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 9.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 10.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 11.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 12.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 13.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 14.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 15.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 16.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 17.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 18.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 19.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 20.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 21.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 22.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 23.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 24.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 25.
# Agent thread joined, scoring 2 points.
# Agent thread started, epoch 26.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 27.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 28.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 29.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 30.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 31.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 32.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 33.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 34.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 35.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 36.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 37.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 38.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 39.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 40.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 41.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 42.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 43.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 44.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 45.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 46.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 47.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 48.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 49.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 50.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 51.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 52.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 53.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 54.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 55.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 56.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 57.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 58.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 59.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 60.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 61.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 62.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 63.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 64.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 65.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 66.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 67.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 68.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 69.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 70.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 71.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 72.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 73.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 74.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 75.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 76.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 77.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 78.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 79.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 80.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 81.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 82.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 83.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 84.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 85.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 86.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 87.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 88.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 89.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 90.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 91.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 92.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 93.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 94.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 95.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 96.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 97.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 98.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 99.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 100.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 101.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 102.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 103.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 104.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 105.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 106.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 107.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 108.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 109.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 110.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 111.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 112.
# Agent thread joined, scoring 1 points.
# Agent thread started, epoch 113.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 114.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 115.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 116.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 117.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 118.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 119.
# Agent thread joined, scoring 0 points.
# Agent thread started, epoch 120.
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-9-f7e329d5b0c3> in <module>
#       7     agent_thread.start()
#       8
# ----> 9     game.start(return_queue)
#      10     agent_thread.join()
#      11
#
# c:\Users\jason\Documents\Code Projects\MLSnake\snake.py in start(self, return_queue)
#     252         while self.running:
#     253             if self.step_queue.full():
# --> 254                 self.update()
#     255
#     256
#
# c:\Users\jason\Documents\Code Projects\MLSnake\snake.py in update(self)
#     202                 self.snake_list.insert(0, last_segment)
#     203
# --> 204             self.draw_update()
#     205         else:
#     206             self.running = False
#
# c:\Users\jason\Documents\Code Projects\MLSnake\snake.py in draw_update(self)
#     110         Updates the entire GUI, and animates a frame.
#     111         '''
# --> 112         self.canvas.delete("all")
#     113         self.canvas.create_text(30, 10, fill="white", text="Score: " +
#     114                                 str(self.score))
#
# ~\anaconda3\envs\MLSnake\lib\tkinter\__init__.py in delete(self, *args)
#    2512     def delete(self, *args):
#    2513         """Delete items identified by all tag or ids contained in ARGS."""
# -> 2514         self.tk.call((self._w, 'delete') + args)
#    2515     def dtag(self, *args):
#    2516         """Delete tag or id given as last arguments in ARGS from items
#
# TclError: invalid command name ".!canvas"
